# %% [markdown]
# <a href="https://colab.research.google.com/github/Nattapat140/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Student Information**
# Name: 許裕華
#
# Student ID: 111006203
#
# GitHub ID: 120806677
#
# Kaggle name: Nattapat6203
#
# Kaggle private scoreboard snapshot:
# ![Screenshot 2568-12-02 at 19.35.29.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # **Instructions**

# %% [markdown]
# For this lab we have divided the assignments into **three phases/parts**. The `first two phases` refer to the `exercises inside the Master notebooks` of the [DM2025-Lab2-Exercise Repo](https://github.com/difersalest/DM2025-Lab2-Exercise.git). The `third phase` refers to an `internal Kaggle competition` that we are gonna run among all the Data Mining students. Together they add up to `100 points` of your grade. There are also some `bonus points` to be gained if you complete `extra exercises` in the lab **(bonus 15 pts)** and in the `Kaggle Competition report` **(bonus 5 pts)**.
#
# **Environment recommendations to solve lab 2:**
# - **Phase 1 exercises:** Need GPU for training the models explained in that part, if you don't have a GPU in your laptop it is recommended to run in Colab or Kaggle for a faster experience, although with CPU they can still be solved but with a slower execution.
# - **Phase 2 exercises:** We use Gemini's API so everything can be run with only CPU without a problem.
# - **Phase 3 exercises:** For the competition you will probably need GPU to train your models, so it is recommended to use Colab or Kaggle if you don't have a laptop with a dedicated GPU.
# - **Optional Ollama Notebook (not graded):** You need GPU, at least 4GB of VRAM with 16 GB of RAM to run the local open-source LLM models.
#
# ## **Phase 1 (30 pts):**
#
# 1. __Main Exercises (25 pts):__ Do the **take home exercises** from Sections: `1. Data Preparation` to `9. High-dimension Visualization: t-SNE and UMAP`, in the [DM2025-Lab2-Master-Phase_1 Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_1.ipynb). Total: `8 exercises`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 3th, 11:59 pm, Monday)`**
#
# 2. **Code Comments (5 pts):** **Tidy up the code in your notebook**.
#
# ## **Phase 2 (30 pts):**
#
# 1. **Main Exercises (25 pts):** Do the remaining **take home exercises** from Section: `2. Large Language Models (LLMs)` in the [DM2025-Lab2-Master-Phase_2_Main Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Main.ipynb). Total: `5 exercises required from sections 2.1, 2.2, 2.4 and 2.6`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**
#
# 2. **Code Comments (5 pts):** **Tidy up the code in your notebook**.
#
# 3. **`Bonus (15 pts):`** Complete the bonus exercises in the [DM2025-Lab2-Master-Phase_2_Bonus Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Bonus.ipynb) and [DM2025-Lab2-Master-Phase_2_Main Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Main.ipynb) `where 2 exercises are counted as bonus from sections 2.3 and 2.5 in the main notebook`. Total: `7 exercises`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**
#
# ## **Phase 3 (40 pts):**
#
# 1. **Kaggle Competition Participation (30 pts):** Participate in the in-class **Kaggle Competition** regarding Emotion Recognition on Twitter by clicking in this link: **[Data Mining Class Kaggle Competition](https://www.kaggle.com/t/3a2df4c6d6b4417e8bf718ed648d7554)**. The scoring will be given according to your place in the Private Leaderboard ranking:
#     - **Bottom 40%**: Get 20 pts of the 30 pts in this competition participation part.
#
#     - **Top 41% - 100%**: Get (0.6N + 1 - x) / (0.6N) * 10 + 20 points, where N is the total number of participants, and x is your rank. (ie. If there are 100 participants and you rank 3rd your score will be (0.6 * 100 + 1 - 3) / (0.6 * 100) * 10 + 20 = 29.67% out of 30%.)
#     Submit your last submission **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**. Make sure to take a screenshot of your position at the end of the competition and store it as `pic_ranking.png` under the `pics` folder of this repository and rerun the cell **Student Information**.
#
# 2. **Competition Report (10 pts)** A report section to be filled in inside this notebook in Markdown Format, we already provided you with the template below. You need to describe your work developing the model for the competition. The report should include a section describing briefly the following elements:
# * Your preprocessing steps.
# * The feature engineering steps.
# * Explanation of your model.
#
# * **`Bonus (5 pts):`**
#     * You will have to describe more detail in the previous steps.
#     * Mention different things you tried.
#     * Mention insights you gained.
#
# [Markdown Guide - Basic Syntax](https://www.markdownguide.org/basic-syntax/)
#
# **`Things to note for Phase 3:`**
#
# * **The code used for the competition should be in this Jupyter Notebook File** `DM2025-Lab2-Homework.ipynb`.
#
# * **Push the code used for the competition to your repository**.
#
# * **The code should have a clear separation for the same sections of the report, preprocessing, feature engineering and model explanation. Briefly comment your code for easier understanding, we provide a template at the end of this notebook.**
#
# * Showing the kaggle screenshot of the ranking plus the code in this notebook will ensure the validity of your participation and the report to obtain the corresponding points.
#
# After the competition ends you will have two days more to submit the `DM2025-Lab2-Homework.ipynb` with your report in markdown format and your code. Do everything **`BEFORE the deadline (Nov. 26th, 11:59 pm, Wednesday) to obtain 100% of the available points.`**
#
# Upload your files to your repository then submit the link to it on the corresponding NTU Cool assignment.
#
# ## **Deadlines:**
#
# ![lab2_deadlines](./pics/lab2_deadlines.png)

# %% [markdown]
# ---
#
# Next you will find the template report with some simple markdown syntax explanations, use it to structure your content.
#
# You can delete the syntax suggestions after you use them.
#
# ---

# %% [markdown]
# ***
#
# # **Project Report**
#
# **Syntax:** `#` creates the largest heading (H1).
#
# ---
# **Syntax:** `---` creates a horizontal rule (a separator line).
#
# ## 1. Model Development (10 pts Required)
#
# **Syntax:** `##` creates a secondary heading (H2).
#
# **Describe briefly each section, you can add graphs/charts to support your explanations.**
#
# ### 1.1 Preprocessing Steps
#
# So, this is the step where I cleaned up the raw data to make it usable. I started by loading the **final_posts.json** and merging it with the identification and emotion labels so everything was in one main dataframe. I think it's easier to manage this way.
#
# The raw text from social media is usually pretty messy, so I wrote a simple_clean function using regex. I have tried to over-clean it (like removing stopwords), and the result got worse, because BERT actually needs some of that context, but I did strip out URLs and fixed the weird spacing issues.
#
# Finally, since the data comes in one file, so I have to handle the Data Splitting. I separate the original train vs. test split provided in the files, but I also carved out a 20% validation set from the training data to use as validation.
#
# ### 1.2 Feature Engineering Steps
#
# I used the BERT Tokenizer (bert-base-uncased) to convert the cleaned sentences into input IDs.
#
# I also had to handle the Label Encoding. Since the model cant predict strings like "anger" or "joy," I mapped each emotion to a unique integer (0, 1, 2, etc.)
#
# Then I construct the
# - **The Dataset Class:** This handles how we grab a single data point. It returns the tokenized text and the label.
#
# - The **Collate Function:** This is really important for batching. Since not every tweet is the same length, this function dynamically pads the shorter sentences in a batch with zeros so they all match the length of the longest sentence. At first If I didn't do this, then PyTorch threw errors when trying to stack the tensors.
#
# ### 1.3 Explanation of Your Model
#
# Instead of just using the default BERT classifier, I manually grabbed the last hidden states from BERT and applied Mean Pooling. Basically, I took the average of all the token embeddings in the sentence (ignoring the padding) to get a really robust summary vector of the whole sentence. Then, I passed that vector through a Dropout layer (to prevent overfitting) and a Linear layer to get our final predictions.
#
# For the training loop, I added a few additonal steps:
# - **Class Weights:** I noticed the dataset was imbalanced (joy was dominated), so I calculated weights and passed them to the CrossEntropyLoss. This tells the model to pay more attention to the rare classes, like digust.
#
# - **Checkpointing:** Inside the loop, I set it up to track validation accuracy after every epoch. It only saves the model to best_model_split.ckpt if the accuracy beats the previous best score. This ensures that, I'm testing with the absolute best version of the model.
#
# ---
#
# ## 2. Bonus Section (5 pts Optional)
#
# **Add more detail in previous sections**
#
# ### 2.1 Mention Different Things You Tried
#
# - I have tried using the decision tree, because I thought it could perform well on classify emotion based on the information gain through the text. But the result was worse. So I have shifted towards using pretrained BERT model instead
#
# - During preprocess step, I have tried removing stopwords, but I have learnt that maybe we should not do that because BERT need some stopwords to capture the meaning of the sentence such as "not happy", if we remove "not", then the emotion will be the opposite instantly.
#
# ### 2.2 Mention Insights You Gained
#
# - I have observed that in the dataset the classes are imbalance. So I wrote the function to handle it, but the result was still not that good.
#
# The below image display the class imbalance in the training dataset (%)
#
# ![Screenshot 2568-12-02 at 23.40.35.png](data:image/png;base64,...)
#
# - Some of the sentences are very difficult to classify it's emotion, even with bare eyes, for example, joy and surprise. So I think this could confuse the model.
#
# ---

# %% [markdown]
# **`From here on starts the code section for the competition.`**
#
# ---

# %% [markdown]
# # **Competition Code**
#
# ## 1. Preprocessing Steps

# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split

# --------------- Load Data --------------- #
df_from_file = pd.read_json('/content/final_posts.json')
emotion = pd.read_csv('/content/emotion.csv')
data_iden = pd.read_csv('/content/data_identification.csv')

# ------- Extract data from multiple files and merge them together ------- #
posts_list = [item['_source']['post'] for item in df_from_file['root'].tolist()]
df = pd.json_normalize(posts_list)

df = pd.merge(df, data_iden, left_on='post_id', right_on='id', how='left')
df = df.drop(columns=['id'])

# ------- Split train and test data --------- #
df_train = df[df['split'] == 'train']
df_train = df_train.drop(columns=['split'])
df_train = pd.merge(df_train, emotion, left_on='post_id', right_on='id', how='left')
df_train = df_train.drop(columns=['id'])

df_test = df[df['split'] == 'test']
df_test = df_test.drop(columns=['split'])

# df_train.emotion.value_counts() / df_train.shape[0] *100 # check the number in each emotion class

# ------------ Create Validation Split (80% Train, 20% Val) ------------ #
df_train, df_val = train_test_split(
    df_train,
    test_size=0.2,
    random_state=42,
    stratify=df_train['emotion']
)

# -------------- Text Cleaning Function --------------- #
def simple_clean(text):
    # Remove URLs if any
    text = re.sub(r'http\S+', '', text)
    # Remove extra whitespace if any
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Apply cleaning
df_train['text'] = df_train['text'].apply(simple_clean)
df_test['text'] = df_test['text'].apply(simple_clean)
df_val['text'] = df_val['text'].apply(simple_clean) # Ensure val is cleaned too

# %% [markdown]
# ## 2. Feature Engineering Steps

# %%
### Add the code related to the feature engineering steps in cells inside this section
import torch
from transformers import BertTokenizer
from torch.utils.data import Dataset, DataLoader

# This is inspired from the hw3 in NLP course

# -------------- Label Encoding -------------- #
classes = sorted(df_train['emotion'].unique())
label2id = {label: idx for idx, label in enumerate(classes)}
id2label = {idx: label for label, idx in label2id.items()}

df_train['label'] = df_train['emotion'].map(label2id)
df_val['label'] = df_val['emotion'].map(label2id)

# ------------ Tokenizer Initialization ------------ #
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
device = "cuda" if torch.cuda.is_available() else "cpu"

# ------------ Construct Dataset Class ---------- # For dataloader later
class EmotionDataset(Dataset):
    def __init__(self, dataframe, tokenizer, classes, has_labels=True):
        self.dataframe = dataframe
        self.tokenizer = tokenizer
        self.classes = classes
        self.text = self.dataframe.text.to_numpy()
        self.has_labels = has_labels

        if self.has_labels:
            if 'emotion' not in self.dataframe.columns:
                raise ValueError("DataFrame must contain 'emotion' column when has_labels is True.")
            if 'label' in self.dataframe.columns:
                self.labels = self.dataframe.label.to_numpy()
            else:
                label_map = {label: i for i, label in enumerate(self.classes)}
                self.labels = [label_map[l] for l in self.dataframe.emotion.to_numpy()]
        else:
            self.labels = None

    def __len__(self):
        return len(self.text)

    def __getitem__(self, idx):
        text = self.text[idx]
        item = {'text': text}
        if self.has_labels:
            label = self.labels[idx]
            item['emotion'] = label
        return item

# ------------ Collate Function (Padding) ------------ #
def collate_fn(batch):
    texts = [data['text'] for data in batch]
    encoding = tokenizer(
        texts,
        padding=True,
        truncation=True,
        return_tensors="pt"
    )

    if 'emotion' in batch[0]:
        labels = [data['emotion'] for data in batch]
        encoding['emotion'] = torch.tensor(labels, dtype=torch.long)

    encoding = {k: encoding[k].to(device) for k in encoding}
    return encoding

# ------------- DataLoaders Setup for training ------------- #
train_batch_size = 32
dl_train = DataLoader(EmotionDataset(df_train, tokenizer, classes, has_labels=True),
                      batch_size=train_batch_size, shuffle=True, collate_fn=collate_fn)
dl_val = DataLoader(EmotionDataset(df_val, tokenizer, classes, has_labels=True),
                    batch_size=1, shuffle=True, collate_fn=collate_fn)
dl_test = DataLoader(EmotionDataset(df_test, tokenizer, classes, has_labels=False),
                     batch_size=1, shuffle=False, collate_fn=collate_fn)

# %% [markdown]
# ## 3. Model Implementation Steps

# %%
### Add the code related to the model implementation steps in cells inside this section
import torch
from torch import nn
from torch.optim import AdamW
from transformers import BertModel, get_linear_schedule_with_warmup
from sklearn.utils.class_weight import compute_class_weight
from tqdm import tqdm

# ---------------- Model Architecture ---------------- #
class main_model(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.bert = BertModel.from_pretrained("google-bert/bert-base-uncased")
        self.dropout = torch.nn.Dropout(p=0.3) # try 0.4, 0.5
        self.classification_head = torch.nn.Linear(768, num_classes)

    def forward(self, **kwargs): #forward func for prediciton
        outputs = self.bert(
            input_ids=kwargs['input_ids'],
            attention_mask=kwargs['attention_mask']
        )
        last_hidden_state = outputs.last_hidden_state
        input_mask_expanded = kwargs['attention_mask'].unsqueeze(-1).expand(last_hidden_state.size()).float()
        sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
        mean_pooled = sum_embeddings / sum_mask

        mean_pooled = self.dropout(mean_pooled)
        emotion = self.classification_head(mean_pooled)
        return {'emotion': emotion}

# -------------- Configuration hyperparameter ------------- #
lr = 3e-5
epochs = 10
model = main_model(num_classes=len(classes)).to(device)
optimizer = AdamW(model.parameters(), lr=lr)

num_training_steps = len(dl_train) * epochs
num_warmup_steps = int(0.1 * num_training_steps)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=num_warmup_steps, num_training_steps=num_training_steps) #setup scheduler

# ------------ Compute Class Weights for Imbalanced Data ------------ #
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.array(list(label2id.values())),
    y=df_train['label'].values
)
class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)
classification_loss = torch.nn.CrossEntropyLoss(weight=class_weights)

# ------------- Training Loop ------------- #
best_val_accuracy = 0
model_save_path = 'best_model_split.ckpt'

for ep in range(epochs):
    pbar = tqdm(dl_train)
    pbar.set_description(f"Training epoch [{ep+1}/{epochs}]")
    model.train()

    for batch in pbar:
        optimizer.zero_grad()
        outputs = model(
            input_ids=batch['input_ids'],
            attention_mask=batch['attention_mask']
        )
        loss = classification_loss(outputs['emotion'], batch['emotion'])
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        scheduler.step()

    #Val Step
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for batch in dl_val:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            preds = torch.argmax(outputs['emotion'], dim=1)
            labels = batch['emotion'].to(device)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    val_acc = correct / total
    print(f"Epoch {ep+1} Validation Accuracy: {val_acc:.4f}")
    # save the model's state only the val accuracy is higher
    if val_acc > best_val_accuracy:
        best_val_accuracy = val_acc
        torch.save(model.state_dict(), model_save_path)
        print("New best model saved!")

# ---------- Prediction --------- #
model.load_state_dict(torch.load(model_save_path, weights_only=True))
model.eval()

all_preds_class = []
pbar_test = tqdm(dl_test, desc="Test")

with torch.no_grad():
    for batch in pbar_test:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        preds_class = torch.argmax(outputs['emotion'], dim=1)
        all_preds_class.extend(preds_class.cpu().tolist())

#Create Submission file
final_df = pd.DataFrame({
    'id': df_test['post_id'].reset_index(drop=True),
    'emotion': [classes[pred_id] for pred_id in all_preds_class]
})
final_df.to_csv('final_df_.csv', index=False)
